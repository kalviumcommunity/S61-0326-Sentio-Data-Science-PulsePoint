# %%
# 1. Defining a Function
def greet_user(name):
    """Prints a greeting message to the user."""
    print(f"Hello, {name}! Welcome to the Python functions lesson.")

# 2. Calling a Function
greet_user("Meghana")

# 3. Using Parameters and Arguments
def add_numbers(a, b):
    """Returns the sum of two numbers."""
    return a + b

result = add_numbers(6, 7)
print("Sum:", result)

# 4. Understanding Function Scope (Basics)
message = "Global message"

def print_message():
    message = "Local message"
    print("Inside function:", message)

print_message()
print("Outside function:", message)
# Out:
# Hello, Meghana! Welcome to the Python functions lesson.
# Sum: 13
# Inside function: Local message
# Outside function: Global message
