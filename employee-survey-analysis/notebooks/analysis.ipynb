# %% [markdown]
# ## 4. When to Restart vs. Interrupt
#
# - **Interrupt** is useful for stopping a cell that is taking too long or is stuck, but it does not clear variables or memory.
# - **Restart** is used to reset the entire notebook state, clearing all variables and memory. This is essential for debugging and ensuring reproducibility.
#
# **Summary:**
# - Use **Interrupt** for stuck/long-running code.
# - Use **Restart** to clear all state and start fresh, especially before re-running all cells for a clean result.

# %%
# This cell will run indefinitely until interrupted
import time
while True:
    time.sleep(1)

# %% [markdown]
# ## 3. Interrupting Execution
#
# - Run the following cell to start a long-running operation.
# - Use the **Interrupt** option in the Jupyter menu to stop it.
# - Confirm that the notebook remains responsive after interruption.

# %% [markdown]
# ## 2. Restarting the Kernel
#
# - Use the Jupyter menu to **Restart Kernel**.
# - After restarting, try running only the print cell above. You should see an error because the variable `a` is no longer defined.
# - Rerun the first cell (defining `a`), then the print cell, to restore the state.

# %%
# Print the variable
printf(a)

# %%
# Define a variable
a = 10

# %% [markdown]
# ## 1. Running Cells and Understanding Execution Order
#
# - Run the following cells in order and observe the outputs.
# - Try running the second cell before the first to see what happens.

# %% [markdown]
# # Jupyter Kernel Control and Debugging
#
# This notebook demonstrates how to run, restart, and interrupt Jupyter kernels. Mastering these actions is essential for debugging, reproducibility, and maintaining a clean notebook state during data science work.

# %% [markdown]
# # Code Cells and Markdown Cells in Jupyter Notebook
#
# This notebook demonstrates how to use **Code** cells for execution and **Markdown** cells for explanation.

# %% [markdown]
# ## Purpose of This Notebook
#
# This notebook is part of a fundamentals milestone.
#
# - Code cells are used to run Python
# - Markdown cells are used to explain what the notebook is doing
# - Keeping them separate makes notebooks easier to read and review

# %% [markdown]
# ## Example 1: A Simple Code Cell
#
# The next cell runs a basic Python command. This is a **Code** cell because it performs execution and produces output.

# %%
print("Hello from a Code cell!")
# Out:
# Hello from a Code cell!

# %% [markdown]
# ## Example 2: Another Code Cell
#
# This next cell stores values in variables and performs a small calculation. The explanation belongs here in Markdown, while the computation belongs in the Code cell below.

# %%
a = 7
b = 8
total = a + b
print("The sum is:", total)
# Out:
# The sum is: 15

# %% [markdown]
# ## When to Use Each Cell Type
#
# **Use a Code cell when you want to:**
#
# - Run Python
# - Create variables
# - Perform calculations
# - Display output
#
# **Use a Markdown cell when you want to:**
#
# - Add a title or section heading
# - Explain what the next code cell does
# - Describe results in words
# - Make the notebook readable for other people

# %% [markdown]
# ## Practicing Cell Switching
#
# In Jupyter Notebook, you can change a cell type from the toolbar or by using command mode:
#
# - Press `Esc` then `M` to convert a cell to Markdown
# - Press `Esc` then `Y` to convert a cell to Code
#
# This helps fix mistakes and keeps the notebook organized.
