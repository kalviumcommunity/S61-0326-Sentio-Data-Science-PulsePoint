# %% [markdown]
# # Markdown Practice in Jupyter Notebook
#
# ## 1. Understanding Markdown Cells
#
# Markdown cells are used to explain the logic and structure of the notebook.

# %% [markdown]
# ### Key Features of Markdown
#
# - Easy to write
# - Improves readability
# - Helps structure notebooks

# %% [markdown]
# ### Steps to Use Markdown
#
# 1. Select Markdown cell
# 2. Write content using syntax
# 3. Run the cell

# %% [markdown]
# ### Inline Code Example
#
# The `print()` function is used to display output.

# %% [markdown]
# ### Code Block Example
#
# ```python
# print("Hello, Markdown!")

# %% [markdown]
# print("This is a code cell")

# %% [markdown]
# ### Explanation
#
# The above code prints a simple message. Markdown helps explain what the code is doing.
